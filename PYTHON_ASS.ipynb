# %% [markdown]
# **Exercise 1: Prime Numbers**
#
# Write a Python program that checks whether a given number is prime or not. A prime number is a natural number greater than 1 that has no positive divisors other than 1 and itself.

# %%
num = int(input('enter number :')) # taking input from the user
if num >1:

    for i in range(2,num//2+1): # take range from 2 to off of the given number
        if num%2==0:
            # check the number is divisible by any number or not

            print( num," is not prime number")
            break
        else:
            print(num, " is prime number")
            break
else:

    print(num,'is not prime number ')     #if given number is less than 1 then it will give error
# Out:
# enter number :5
# 5  is prime number

# %% [markdown]
# **Exercise 2: Product of Random Numbers**
#
# Develop a Python program that generates two random numbers and asks the user to enter the product of these numbers. The program should then check if the user's answer is correct and display an appropriate message.

# %%
import random

# Generate two random numbers between 1 and 10
num1 = random.randint(1, 10)
num2 = random.randint(1, 10)

# Calculate the correct product
correct_product = num1 * num2

# Ask the user to enter their answer
user_answer = int(input(f"What is the product of {num1} and {num2}:- "))

# Check if the user's answer is correct
if user_answer == correct_product:
    print("Correct! Well done.")
else:
    print(f"Incorrect. The correct answer is {correct_product}.")
# Out:
# What is the product of 9 and 9:- 18
# Incorrect. The correct answer is 81.

# %% [markdown]
# **Exercise 3: Squares of Even/Odd Numbers**
#
# Create a Python script that prints the squares of all even or odd numbers within the range of 100 to 200. Choose either even or odd numbers and document your choice in the code.

# %%
for i in range(10, 100): # taking number 10 to 100

    if i%2==0: # finding even umber
        print("The even ", i,'and the sqaures nuber',i**2) # Squares the even number
# Out:
# The even  10 and the sqaures nuber 100
# The even  12 and the sqaures nuber 144
# The even  14 and the sqaures nuber 196
# The even  16 and the sqaures nuber 256
# The even  18 and the sqaures nuber 324
# The even  20 and the sqaures nuber 400
# The even  22 and the sqaures nuber 484
# The even  24 and the sqaures nuber 576
# The even  26 and the sqaures nuber 676
# The even  28 and the sqaures nuber 784
# The even  30 and the sqaures nuber 900
# The even  32 and the sqaures nuber 1024
# The even  34 and the sqaures nuber 1156
# The even  36 and the sqaures nuber 1296
# The even  38 and the sqaures nuber 1444
# The even  40 and the sqaures nuber 1600
# The even  42 and the sqaures nuber 1764
# The even  44 and the sqaures nuber 1936
# The even  46 and the sqaures nuber 2116
# The even  48 and the sqaures nuber 2304
# The even  50 and the sqaures nuber 2500
# The even  52 and the sqaures nuber 2704
# The even  54 and the sqaures nuber 2916
# The even  56 and the sqaures nuber 3136
# The even  58 and the sqaures nuber 3364
# The even  60 and the sqaures nuber 3600
# The even  62 and the sqaures nuber 3844
# The even  64 and the sqaures nuber 4096
# The even  66 and the sqaures nuber 4356
# The even  68 and the sqaures nuber 4624
# The even  70 and the sqaures nuber 4900
# The even  72 and the sqaures nuber 5184
# The even  74 and the sqaures nuber 5476
# The even  76 and the sqaures nuber 5776
# The even  78 and the sqaures nuber 6084
# The even  80 and the sqaures nuber 6400
# The even  82 and the sqaures nuber 6724
# The even  84 and the sqaures nuber 7056
# The even  86 and the sqaures nuber 7396
# The even  88 and the sqaures nuber 7744
# The even  90 and the sqaures nuber 8100
# The even  92 and the sqaures nuber 8464
# The even  94 and the sqaures nuber 8836
# The even  96 and the sqaures nuber 9216
# The even  98 and the sqaures nuber 9604

# %% [markdown]
# **Exercise 4: Word counter**
#
# write a program to count the number of words in a given text.

# %%
input_text="This is a sample text. This text will be used to demonstrate the word counter." # user text input

def count_words(input_text):
  words=input_text.split() # split the text into a list of words based on spaces
  word_count={} # creating empty dictionary to store the word count
  for i in words:
    if i in word_count: #loop through each word in the list
      word_count[i]+=1 # if the word is already in the dictionary, increment its count by 1
    else: # if the word is not in the dictionary, add it with an initial count of 1
      word_count[i]=1
  return word_count # return the dictionary containing words and their counts
result=count_words(input_text) # calling the function, and storing in result
print(result)
# Out:
# {'This': 2, 'is': 1, 'a': 1, 'sample': 1, 'text.': 1, 'text': 1, 'will': 1, 'be': 1, 'used': 1, 'to': 1, 'demonstrate': 1, 'the': 1, 'word': 1, 'counter.': 1}

# %% [markdown]
# **Exercise 5: Check for Palindrome**
#
# Write a Python function called is_palindrome that takes a string as input and returns True if the string is a palindrome, and False otherwise. A palindrome is a word, phrase, number, or other sequence of characters that reads the same forward and backward, ignoring spaces, punctuation, and capitalization.

# %%
import string
def is_palindrome(text):
    text = text.lower() # Convert to lowercase
    cleaned_text = ''.join(char for char in text if char.isalnum())# Remove spaces and punctuation
    return cleaned_text == cleaned_text[::-1]    # Check if the cleaned text reads the same forward and backward
# Example usage
print(is_palindrome("racecar"))# True
# Out:
# True
