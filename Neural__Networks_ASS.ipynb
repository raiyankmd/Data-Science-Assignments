# %% [markdown]
# **Data Exploration and Preprocessing:**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('/content/Alphabets_data.csv')
df
# Out:
#       letter  xbox  ybox  width  height  onpix  xbar  ybar  x2bar  y2bar  \
# 0          T     2     8      3       5      1     8    13      0      6
# 1          I     5    12      3       7      2    10     5      5      4
# 2          D     4    11      6       8      6    10     6      2      6
# 3          N     7    11      6       6      3     5     9      4      6
# 4          G     2     1      3       1      1     8     6      6      6
# ...      ...   ...   ...    ...     ...    ...   ...   ...    ...    ...
# 19995      D     2     2      3       3      2     7     7      7      6
# 19996      C     7    10      8       8      4     4     8      6      9
# 19997      T     6     9      6       7      5     6    11      3      7
# 19998      S     2     3      4       2      1     8     7      2      6
# 19999      A     4     9      6       6      2     9     5      3      1
#
#        xybar  x2ybar  xy2bar  xedge  xedgey  yedge  yedgex
# 0          6      10       8      0       8      0       8
# 1         13       3       9      2       8      4      10
# 2         10       3       7      3       7      3       9
# 3          4       4      10      6      10      2       8
# 4          6       5       9      1       7      5      10
# ...      ...     ...     ...    ...     ...    ...     ...
# 19995      6       6       4      2       8      3       7
# 19996     12       9      13      2       9      3       7
# 19997     11       9       5      2      12      2       4
# 19998     10       6       8      1       9      5       8
# 19999      8       1       8      2       7      2       8
#
# [20000 rows x 17 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   letter  20000 non-null  object
#  1   xbox    20000 non-null  int64
#  2   ybox    20000 non-null  int64
#  3   width   20000 non-null  int64
#  4   height  20000 non-null  int64
#  5   onpix   20000 non-null  int64
#  6   xbar    20000 non-null  int64
#  7   ybar    20000 non-null  int64
#  8   x2bar   20000 non-null  int64
#  9   y2bar   20000 non-null  int64
#  10  xybar   20000 non-null  int64
#  11  x2ybar  20000 non-null  int64
#  12  xy2bar  20000 non-null  int64
#  13  xedge   20000 non-null  int64
#  14  xedgey  20000 non-null  int64
#  15  yedge   20000 non-null  int64
#  16  yedgex  20000 non-null  int64
# dtypes: int64(16), object(1)
# memory usage: 2.6+ MB

# %%
df.describe()
# Out:
#                xbox          ybox         width       height         onpix  \
# count  20000.000000  20000.000000  20000.000000  20000.00000  20000.000000
# mean       4.023550      7.035500      5.121850      5.37245      3.505850
# std        1.913212      3.304555      2.014573      2.26139      2.190458
# min        0.000000      0.000000      0.000000      0.00000      0.000000
# 25%        3.000000      5.000000      4.000000      4.00000      2.000000
# 50%        4.000000      7.000000      5.000000      6.00000      3.000000
# 75%        5.000000      9.000000      6.000000      7.00000      5.000000
# max       15.000000     15.000000     15.000000     15.00000     15.000000
#
#                xbar          ybar         x2bar         y2bar         xybar  \
# count  20000.000000  20000.000000  20000.000000  20000.000000  20000.000000
# mean       6.897600      7.500450      4.628600      5.178650      8.282050
# std        2.026035      2.325354      2.699968      2.380823      2.488475
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        6.000000      6.000000      3.000000      4.000000      7.000000
# 50%        7.000000      7.000000      4.000000      5.000000      8.000000
# 75%        8.000000      9.000000      6.000000      7.000000     10.000000
# max       15.000000     15.000000     15.000000     15.000000     15.000000
#
#             x2ybar        xy2bar         xedge        xedgey         yedge  \
# count  20000.00000  20000.000000  20000.000000  20000.000000  20000.000000
# mean       6.45400      7.929000      3.046100      8.338850      3.691750
# std        2.63107      2.080619      2.332541      1.546722      2.567073
# min        0.00000      0.000000      0.000000      0.000000      0.000000
# 25%        5.00000      7.000000      1.000000      8.000000      2.000000
# 50%        6.00000      8.000000      3.000000      8.000000      3.000000
# 75%        8.00000      9.000000      4.000000      9.000000      5.000000
# max       15.00000     15.000000     15.000000     15.000000     15.000000
#
#             yedgex
# count  20000.00000
# mean       7.80120
# std        1.61747
# min        0.00000
# 25%        7.00000
# 50%        8.00000
# 75%        9.00000
# max       15.00000

# %%
df.isnull().sum()
# Out:
# letter    0
# xbox      0
# ybox      0
# width     0
# height    0
# onpix     0
# xbar      0
# ybar      0
# x2bar     0
# y2bar     0
# xybar     0
# x2ybar    0
# xy2bar    0
# xedge     0
# xedgey    0
# yedge     0
# yedgex    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(1332)

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['letter'].unique()
# Out:
# array(['T', 'I', 'D', 'N', 'G', 'S', 'B', 'A', 'J', 'M', 'X', 'O', 'R',
#        'F', 'C', 'H', 'W', 'L', 'P', 'E', 'V', 'Y', 'Q', 'U', 'K', 'Z'],
#       dtype=object)

# %%
from sklearn.preprocessing import MinMaxScaler

x = df.drop(columns=['letter'])
y = df['letter']

#mimax scaler
scaler = MinMaxScaler()
x_scaled = scaler.fit_transform(x)

# %%
from sklearn.preprocessing import OneHotEncoder

# One-hot encode the target variable
encoder = OneHotEncoder()
y_encode = encoder.fit_transform(y.values.reshape(-1, 1))
y_encoded = pd.DataFrame(y_encode.toarray())

# %% [markdown]
# **Model Implementation:**

# %%
from sklearn.model_selection import train_test_split

# split into train and test
x_train, x_test, y_train, y_test = train_test_split(x_scaled, y_encoded, test_size=0.2, random_state=42)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model1 = Sequential([
    Dense(12, activation='relu', input_shape=(x_train.shape[1],)),
    Dense(26, activation='softmax')
])

# since its a multiclass classification problem so im using relu for hidden layer and softmax for output layer

# %%
model1.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
#I'm using adam optimizer bcz it uses both adagrad and rmsprop properties

# %%
training = model1.fit(x_train, y_encoded, epochs=20, batch_size=20, validation_split=0.2)
# Out:
# Epoch 1/20
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.0390 - loss: 3.2680 - val_accuracy: 0.0372 - val_loss: 3.2581
# Epoch 2/20
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.0405 - loss: 3.2576 - val_accuracy: 0.0331 - val_loss: 3.2575
# Epoch 3/20
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.0424 - loss: 3.2556 - val_accuracy: 0.0392 - val_loss: 3.2573
# Epoch 4/20
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.0403 - loss: 3.2552 - val_accuracy: 0.0368 - val_loss: 3.2578
# Epoch 5/20
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0408 - loss: 3.2556 - val_accuracy: 0.0398 - val_loss: 3.2570
# Epoch 6/20
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.0439 - loss: 3.2561 - val_accuracy: 0.0365 - val_loss: 3.2573
# Epoch 7/20
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.0427 - loss: 3.2542 - val_accuracy: 0.0388 - val_loss: 3.2578
# Epoch 8/20
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0424 - loss: 3.2560 - val_accuracy: 0.0362 - val_loss: 3.2574
# Epoch 9/20
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.0449 - loss: 3.2550 - val_accuracy: 0.0365 - val_loss: 3.2575
# Epoch 10/20
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.0450 - loss: 3.2553 - val_accuracy: 0.0405 - val_loss: 3.2574
# Epoch 11/20
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.0463 - loss: 3.2539 - val_accuracy: 0.0368 - val_loss: 3.2577
# Epoch 12/20
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.0462 - loss: 3.2536 - val_accuracy: 0.0382 - val_loss: 3.2578
# Epoch 13/20
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.0443 - loss: 3.2537 - val_accuracy: 0.0368 - val_loss: 3.2574
# Epoch 14/20
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.0483 - loss: 3.2527 - val_accuracy: 0.0378 - val_loss: 3.2575
# Epoch 15/20
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.0466 - loss: 3.2533 - val_accuracy: 0.0402 - val_loss: 3.2580
# Epoch 16/20
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.0476 - loss: 3.2520 - val_accuracy: 0.0372 - val_loss: 3.2579
# Epoch 17/20
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.0482 - loss: 3.2533 - val_accuracy: 0.0352 - val_loss: 3.2574
# Epoch 18/20
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.0506 - loss: 3.2521 - val_accuracy: 0.0402 - val_loss: 3.2575
# Epoch 19/20
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.0508 - loss: 3.2502 - val_accuracy: 0.0412 - val_loss: 3.2587
# Epoch 20/20
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.0444 - loss: 3.2518 - val_accuracy: 0.0395 - val_loss: 3.2586

# %% [markdown]
# **Hyperparameter Tuning:**

# %%
model2 = Sequential([
    Dense(56, activation='relu', input_shape=(x_train.shape[1],)),
    Dense(26, activation='sigmoid')
])
model2.compile(optimizer='RMSprop', loss='categorical_crossentropy', metrics=['accuracy'])
training = model2.fit(x_train, y_encoded, epochs=20, batch_size=42, validation_split=0.2)
# Out:
# Epoch 1/20
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.0406 - loss: 3.2668 - val_accuracy: 0.0385 - val_loss: 3.2604
# Epoch 2/20
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0403 - loss: 3.2580 - val_accuracy: 0.0392 - val_loss: 3.2592
# Epoch 3/20
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0425 - loss: 3.2554 - val_accuracy: 0.0402 - val_loss: 3.2575
# Epoch 4/20
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0438 - loss: 3.2551 - val_accuracy: 0.0422 - val_loss: 3.2584
# Epoch 5/20
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0500 - loss: 3.2544 - val_accuracy: 0.0388 - val_loss: 3.2583
# Epoch 6/20
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0470 - loss: 3.2532 - val_accuracy: 0.0398 - val_loss: 3.2605
# Epoch 7/20
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0494 - loss: 3.2521 - val_accuracy: 0.0395 - val_loss: 3.2586
# Epoch 8/20
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0497 - loss: 3.2518 - val_accuracy: 0.0408 - val_loss: 3.2581
# Epoch 9/20
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0445 - loss: 3.2508 - val_accuracy: 0.0415 - val_loss: 3.2591
# Epoch 10/20
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0505 - loss: 3.2493 - val_accuracy: 0.0429 - val_loss: 3.2574
# Epoch 11/20
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0504 - loss: 3.2490 - val_accuracy: 0.0408 - val_loss: 3.2576
# Epoch 12/20
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0478 - loss: 3.2480 - val_accuracy: 0.0402 - val_loss: 3.2581
# Epoch 13/20
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0502 - loss: 3.2484 - val_accuracy: 0.0435 - val_loss: 3.2576
# Epoch 14/20
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0509 - loss: 3.2495 - val_accuracy: 0.0392 - val_loss: 3.2613
# Epoch 15/20
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0500 - loss: 3.2472 - val_accuracy: 0.0388 - val_loss: 3.2587
# Epoch 16/20
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0499 - loss: 3.2463 - val_accuracy: 0.0388 - val_loss: 3.2595
# Epoch 17/20
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0524 - loss: 3.2466 - val_accuracy: 0.0358 - val_loss: 3.2592
# Epoch 18/20
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0522 - loss: 3.2454 - val_accuracy: 0.0372 - val_loss: 3.2594
# Epoch 19/20
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0510 - loss: 3.2443 - val_accuracy: 0.0372 - val_loss: 3.2605
# Epoch 20/20
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0520 - loss: 3.2450 - val_accuracy: 0.0392 - val_loss: 3.2605

# %%
model3 = Sequential([
    Dense(56, activation='elu', input_shape=(x_train.shape[1],)),
    Dense(26, activation='sigmoid')
])
model3.compile(optimizer='RMSprop', loss='categorical_crossentropy', metrics=['accuracy'])
training = model3.fit(x_train, y_encoded, epochs=20, batch_size=42, validation_split=0.2)
# Out:
# Epoch 1/20
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.0356 - loss: 3.2676 - val_accuracy: 0.0362 - val_loss: 3.2623
# Epoch 2/20
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0358 - loss: 3.2620 - val_accuracy: 0.0398 - val_loss: 3.2602
# Epoch 3/20
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0413 - loss: 3.2574 - val_accuracy: 0.0425 - val_loss: 3.2613
# Epoch 4/20
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0413 - loss: 3.2555 - val_accuracy: 0.0408 - val_loss: 3.2614
# Epoch 5/20
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0446 - loss: 3.2571 - val_accuracy: 0.0358 - val_loss: 3.2635
# Epoch 6/20
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.0456 - loss: 3.2534 - val_accuracy: 0.0382 - val_loss: 3.2606
# Epoch 7/20
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.0472 - loss: 3.2527 - val_accuracy: 0.0362 - val_loss: 3.2601
# Epoch 8/20
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0459 - loss: 3.2513 - val_accuracy: 0.0362 - val_loss: 3.2638
# Epoch 9/20
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0427 - loss: 3.2515 - val_accuracy: 0.0368 - val_loss: 3.2632
# Epoch 10/20
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0472 - loss: 3.2509 - val_accuracy: 0.0462 - val_loss: 3.2623
# Epoch 11/20
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0480 - loss: 3.2460 - val_accuracy: 0.0375 - val_loss: 3.2639
# Epoch 12/20
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0516 - loss: 3.2476 - val_accuracy: 0.0392 - val_loss: 3.2655
# Epoch 13/20
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0490 - loss: 3.2471 - val_accuracy: 0.0392 - val_loss: 3.2661
# Epoch 14/20
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0462 - loss: 3.2502 - val_accuracy: 0.0375 - val_loss: 3.2641
# Epoch 15/20
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0500 - loss: 3.2481 - val_accuracy: 0.0432 - val_loss: 3.2634
# Epoch 16/20
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0518 - loss: 3.2455 - val_accuracy: 0.0415 - val_loss: 3.2642
# Epoch 17/20
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0523 - loss: 3.2476 - val_accuracy: 0.0365 - val_loss: 3.2635
# Epoch 18/20
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0539 - loss: 3.2480 - val_accuracy: 0.0362 - val_loss: 3.2681
# Epoch 19/20
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0540 - loss: 3.2460 - val_accuracy: 0.0398 - val_loss: 3.2663
# Epoch 20/20
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.0473 - loss: 3.2469 - val_accuracy: 0.0372 - val_loss: 3.2677

# %%
model4 = Sequential([
    Dense(56, activation='tanh', input_shape=(x_train.shape[1],)),
    Dense(26, activation='sigmoid')
])
model4.compile(optimizer='ADAgrad', loss='categorical_crossentropy', metrics=['accuracy'])
training = model4.fit(x_train, y_encoded, epochs=20, batch_size=42, validation_split=0.2)
# Out:
# Epoch 1/20
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.0404 - loss: 3.3280 - val_accuracy: 0.0408 - val_loss: 3.3063
# Epoch 2/20
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0356 - loss: 3.2983 - val_accuracy: 0.0408 - val_loss: 3.2897
# Epoch 3/20
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0421 - loss: 3.2778 - val_accuracy: 0.0405 - val_loss: 3.2811
# Epoch 4/20
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0400 - loss: 3.2763 - val_accuracy: 0.0422 - val_loss: 3.2759
# Epoch 5/20
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0388 - loss: 3.2697 - val_accuracy: 0.0405 - val_loss: 3.2726
# Epoch 6/20
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0386 - loss: 3.2681 - val_accuracy: 0.0412 - val_loss: 3.2703
# Epoch 7/20
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0361 - loss: 3.2678 - val_accuracy: 0.0355 - val_loss: 3.2687
# Epoch 8/20
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0417 - loss: 3.2639 - val_accuracy: 0.0388 - val_loss: 3.2675
# Epoch 9/20
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0423 - loss: 3.2618 - val_accuracy: 0.0392 - val_loss: 3.2666
# Epoch 10/20
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0394 - loss: 3.2651 - val_accuracy: 0.0388 - val_loss: 3.2659
# Epoch 11/20
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0421 - loss: 3.2627 - val_accuracy: 0.0415 - val_loss: 3.2654
# Epoch 12/20
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0417 - loss: 3.2623 - val_accuracy: 0.0415 - val_loss: 3.2649
# Epoch 13/20
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.0401 - loss: 3.2621 - val_accuracy: 0.0415 - val_loss: 3.2645
# Epoch 14/20
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.0404 - loss: 3.2612 - val_accuracy: 0.0415 - val_loss: 3.2642
# Epoch 15/20
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0405 - loss: 3.2621 - val_accuracy: 0.0425 - val_loss: 3.2640
# Epoch 16/20
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0426 - loss: 3.2610 - val_accuracy: 0.0425 - val_loss: 3.2638
# Epoch 17/20
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0384 - loss: 3.2613 - val_accuracy: 0.0429 - val_loss: 3.2636
# Epoch 18/20
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0413 - loss: 3.2602 - val_accuracy: 0.0408 - val_loss: 3.2634
# Epoch 19/20
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0396 - loss: 3.2597 - val_accuracy: 0.0408 - val_loss: 3.2633
# Epoch 20/20
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0390 - loss: 3.2604 - val_accuracy: 0.0412 - val_loss: 3.2632

# %% [markdown]
# **Evaluation:**

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import numpy as np
# Get the true labels
y_pred1 = np.argmax(y_test, axis=1)

# Get the predicted labels
y_pred = np.argmax(model1.predict(x_test), axis=1)

accuracy = accuracy_score(y_pred1, y_pred)
precision = precision_score(y_pred1, y_pred, average='weighted')
recall = recall_score(y_pred1, y_pred, average='weighted')
f1 = f1_score(y_pred1, y_pred, average='weighted')
conf_matrix = confusion_matrix(y_pred1, y_pred)

print("Model with relu , softmax and adam optimizer ")
print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1-score: {f1}")
# Out:
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Model with relu , softmax and adam optimizer
# Accuracy: 0.06989823245848956
# Precision: 0.027412025362446912
# Recall: 0.06989823245848956
# F1-score: 0.033333563275137035

# %%
y_pred1 = np.argmax(y_test, axis=1)

# Get the predicted labels
y_pred = np.argmax(model2.predict(x_test), axis=1)

accuracy = accuracy_score(y_pred1, y_pred)
precision = precision_score(y_pred1, y_pred, average='weighted')
recall = recall_score(y_pred1, y_pred, average='weighted')
f1 = f1_score(y_pred1, y_pred, average='weighted')
conf_matrix = confusion_matrix(y_pred1, y_pred)

print("Model with relu , sigmoid and RMSprop")
print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1-score: {f1}")
# Out:
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Model with relu , sigmoid and RMSprop
# Accuracy: 0.07337975361542581
# Precision: 0.04603477440407184
# Recall: 0.07337975361542581
# F1-score: 0.0522361654844772

# %%
y_pred1 = np.argmax(y_test, axis=1)

# Get the predicted labels
y_pred = np.argmax(model3.predict(x_test), axis=1)

accuracy = accuracy_score(y_pred1, y_pred)
precision = precision_score(y_pred1, y_pred, average='weighted')
recall = recall_score(y_pred1, y_pred, average='weighted')
f1 = f1_score(y_pred1, y_pred, average='weighted')
conf_matrix = confusion_matrix(y_pred1, y_pred)

print("Model with elu,sigmoid and RMSprop")
print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1-score: {f1}")
# Out:
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Model with elu,sigmoid and RMSprop
# Accuracy: 0.04177825388323514
# Precision: 0.0344454222122984
# Recall: 0.04177825388323514
# F1-score: 0.027867022352871303

# %%
y_pred1 = np.argmax(y_test, axis=1)

# Get the predicted labels
y_pred = np.argmax(model4.predict(x_test), axis=1)

accuracy = accuracy_score(y_pred1, y_pred)
precision = precision_score(y_pred1, y_pred, average='weighted')
recall = recall_score(y_pred1, y_pred, average='weighted')
f1 = f1_score(y_pred1, y_pred, average='weighted')
conf_matrix = confusion_matrix(y_pred1, y_pred)

print("Model with tanh and Adgrad ")
print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1-score: {f1}")
# Out:
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Model with tanh and Adgrad
# Accuracy: 0.034547402249598284
# Precision: 0.02744368977227269
# Recall: 0.034547402249598284
# F1-score: 0.025425971816585863
